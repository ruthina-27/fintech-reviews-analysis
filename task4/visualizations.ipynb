# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np

# %%
df = pd.read_csv('reviews_with_sentiment.csv')

# %%
plt.title('Sentiment Distribution by Bank', fontweight='bold')
plt.xlabel('Bank', fontsize=12)
plt.ylabel('Percentage (%)', fontsize=12)
plt.xticks(rotation=0)
plt.legend(title='Sentiment', bbox_to_anchor=(1.05, 1))
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %%
for bank in sentiment_percent.index:
    y_offset = 0
    for sentiment in sentiment_percent.columns:
        value = sentiment_percent.loc[bank, sentiment]
        if value > 5:  # Only label segments >5%
            plt.text(bank, y_offset + value/2, f'{value:.1f}%', 
                     ha='center', va='center', color='white' if sentiment == 'negative' else 'black')
        y_offset += value

plt.tight_layout()
plt.savefig('sentiment_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
negative_reviews = df[df['sentiment_label'] == 'negative']

# %%
for i, bank in enumerate(banks, 1):
    text = ' '.join(negative_reviews[negative_reviews['bank'] == bank]['theme'].dropna())
    wordcloud = WordCloud(width=800, height=400, 
                          background_color='white', 
                          colormap='Reds',  # Red scale for pain points
                          max_words=50).generate(text)
    
    plt.subplot(1, 3, i)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'{bank} Pain Points', fontweight='bold')
    plt.axis('off')

plt.tight_layout()
plt.savefig('keyword_clouds.png', dpi=300)
plt.show()
